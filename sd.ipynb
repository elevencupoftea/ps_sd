# %% [markdown]
# ### Prepare Machine

# %%
# !echo $USER
from subprocess import call
# Make Python 3.10 from sources, download dependensies and AUTOMATIC1111's WebUI
call(['chmod', '+x', 'install.sh'])
# !./install.sh
# Out:
# core
# -------------
# Preapring environment
# Collecting GitPython==3.1.32
#   Using cached GitPython-3.1.32-py3-none-any.whl (188 kB)
# Collecting Pillow==9.5.0
#   Using cached Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting accelerate==0.21.0
#   Using cached accelerate-0.21.0-py3-none-any.whl (244 kB)
# Collecting basicsr==1.4.2
#   Using cached basicsr-1.4.2-py3-none-any.whl
# Collecting blendmodes==2022
#   Using cached blendmodes-2022-py3-none-any.whl (10 kB)
# Collecting clean-fid==0.1.35
#   Using cached clean_fid-0.1.35-py3-none-any.whl (26 kB)
# Collecting einops==0.4.1
#   Using cached einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting fastapi==0.94.0
#   Using cached fastapi-0.94.0-py3-none-any.whl (56 kB)
# Collecting gfpgan==1.3.8
#   Using cached gfpgan-1.3.8-py3-none-any.whl (52 kB)
# Collecting gradio==3.41.2
#   Using cached gradio-3.41.2-py3-none-any.whl (20.1 MB)
# Collecting httpcore==0.15
#   Using cached httpcore-0.15.0-py3-none-any.whl (68 kB)
# Collecting inflection==0.5.1
#   Using cached inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting jsonmerge==1.8.0
#   Using cached jsonmerge-1.8.0-py3-none-any.whl
# Collecting kornia==0.6.7
#   Using cached kornia-0.6.7-py2.py3-none-any.whl (565 kB)
# Collecting lark==1.1.2
#   Using cached lark-1.1.2-py2.py3-none-any.whl (104 kB)
# Collecting numpy==1.23.5
#   Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Collecting omegaconf==2.2.3
#   Using cached omegaconf-2.2.3-py3-none-any.whl (79 kB)
# Collecting open-clip-torch==2.20.0
#   Using cached open_clip_torch-2.20.0-py3-none-any.whl (1.5 MB)
# Collecting piexif==1.1.3
#   Using cached piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting psutil==5.9.5
#   Using cached psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
# Collecting pytorch_lightning==1.9.4
#   Using cached pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
# Collecting realesrgan==0.3.0
#   Using cached realesrgan-0.3.0-py3-none-any.whl (26 kB)
# Collecting resize-right==0.0.2
#   Using cached resize_right-0.0.2-py3-none-any.whl (8.9 kB)
# Collecting safetensors==0.3.1
#   Using cached safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting scikit-image==0.21.0
#   Using cached scikit_image-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
# Collecting timm==0.9.2
#   Using cached timm-0.9.2-py3-none-any.whl (2.2 MB)
# Collecting tomesd==0.1.3
#   Using cached tomesd-0.1.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: torch in ./venv/lib/python3.10/site-packages (from -r stable_diffusion/requirements_versions.txt (line 28)) (2.0.1+cu118)
# Collecting torchdiffeq==0.2.3
#   Using cached torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Collecting torchsde==0.2.5
#   Using cached torchsde-0.2.5-py3-none-any.whl (59 kB)
# Collecting transformers==4.30.2
#   Using cached transformers-4.30.2-py3-none-any.whl (7.2 MB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting packaging>=20.0
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting pyyaml
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Collecting tqdm
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: requests in ./venv/lib/python3.10/site-packages (from basicsr==1.4.2->-r stable_diffusion/requirements_versions.txt (line 4)) (2.28.1)
# Collecting addict
#   Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Collecting opencv-python
#   Using cached opencv_python-4.8.0.76-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
# Collecting tb-nightly
#   Using cached tb_nightly-2.15.0a20230914-py3-none-any.whl (5.5 MB)
# Collecting scipy
#   Using cached scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
# Requirement already satisfied: torchvision in ./venv/lib/python3.10/site-packages (from basicsr==1.4.2->-r stable_diffusion/requirements_versions.txt (line 4)) (0.15.2+cu118)
# Collecting yapf
#   Using cached yapf-0.40.1-py3-none-any.whl (250 kB)
# Collecting lmdb
#   Using cached lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
# Collecting future
#   Using cached future-0.18.3.tar.gz (840 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecation<3,>=2.1.0
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting aenum<4,>=3.1.7
#   Using cached aenum-3.1.15-py3-none-any.whl (137 kB)
# Collecting starlette<0.27.0,>=0.26.0
#   Using cached starlette-0.26.1-py3-none-any.whl (66 kB)
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Using cached pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting facexlib>=0.2.5
#   Using cached facexlib-0.3.0-py3-none-any.whl (59 kB)
# Requirement already satisfied: jinja2<4.0 in ./venv/lib/python3.10/site-packages (from gradio==3.41.2->-r stable_diffusion/requirements_versions.txt (line 10)) (3.1.2)
# Collecting python-multipart
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# Collecting websockets<12.0,>=10.0
#   Using cached websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
# Collecting altair<6.0,>=4.2.0
#   Using cached altair-5.1.1-py3-none-any.whl (520 kB)
# Requirement already satisfied: typing-extensions~=4.0 in ./venv/lib/python3.10/site-packages (from gradio==3.41.2->-r stable_diffusion/requirements_versions.txt (line 10)) (4.4.0)
# Collecting importlib-resources<7.0,>=1.3
#   Using cached importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Collecting aiofiles<24.0,>=22.0
#   Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: markupsafe~=2.0 in ./venv/lib/python3.10/site-packages (from gradio==3.41.2->-r stable_diffusion/requirements_versions.txt (line 10)) (2.1.2)
# Collecting pydub
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting matplotlib~=3.0
#   Using cached matplotlib-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Collecting pandas<3.0,>=1.0
#   Using cached pandas-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Collecting semantic-version~=2.0
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting ffmpy
#   Using cached ffmpy-0.3.1-py3-none-any.whl
# Collecting orjson~=3.0
#   Using cached orjson-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
# Collecting gradio-client==0.5.0
#   Using cached gradio_client-0.5.0-py3-none-any.whl (298 kB)
# Collecting httpx
#   Using cached httpx-0.25.0-py3-none-any.whl (75 kB)
# Collecting uvicorn>=0.14.0
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Collecting huggingface-hub>=0.14.0
#   Using cached huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
# Collecting h11<0.13,>=0.11
#   Using cached h11-0.12.0-py3-none-any.whl (54 kB)
# Collecting sniffio==1.*
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting anyio==3.*
#   Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Requirement already satisfied: certifi in ./venv/lib/python3.10/site-packages (from httpcore==0.15->-r stable_diffusion/requirements_versions.txt (line 11)) (2022.12.7)
# Collecting jsonschema
#   Using cached jsonschema-4.19.0-py3-none-any.whl (83 kB)
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting regex
#   Using cached regex-2023.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (771 kB)
# Collecting ftfy
#   Using cached ftfy-6.1.1-py3-none-any.whl (53 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting protobuf<4
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.1 MB/s eta 0:00:00a 0:00:01
# Collecting torchmetrics>=0.7.0
#   Using cached torchmetrics-1.1.2-py3-none-any.whl (764 kB)
# Collecting lightning-utilities>=0.6.0.post0
#   Using cached lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Collecting fsspec[http]>2021.06.0
#   Using cached fsspec-2023.9.0-py3-none-any.whl (173 kB)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
# Collecting imageio>=2.27
#   Using cached imageio-2.31.3-py3-none-any.whl (313 kB)
# Requirement already satisfied: networkx>=2.8 in ./venv/lib/python3.10/site-packages (from scikit-image==0.21.0->-r stable_diffusion/requirements_versions.txt (line 25)) (3.0)
# Collecting lazy_loader>=0.2
#   Using cached lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Collecting tifffile>=2022.8.12
#   Using cached tifffile-2023.8.30-py3-none-any.whl (221 kB)
# Collecting boltons>=20.2.1
#   Using cached boltons-23.0.0-py2.py3-none-any.whl (194 kB)
# Collecting trampoline>=0.1.2
#   Using cached trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from transformers==4.30.2->-r stable_diffusion/requirements_versions.txt (line 31)) (3.9.0)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.10/site-packages (from anyio==3.*->httpcore==0.15->-r stable_diffusion/requirements_versions.txt (line 11)) (3.4)
# Requirement already satisfied: exceptiongroup in ./venv/lib/python3.10/site-packages (from anyio==3.*->httpcore==0.15->-r stable_diffusion/requirements_versions.txt (line 11)) (1.1.3)
# Requirement already satisfied: sympy in ./venv/lib/python3.10/site-packages (from torch->-r stable_diffusion/requirements_versions.txt (line 28)) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in ./venv/lib/python3.10/site-packages (from torch->-r stable_diffusion/requirements_versions.txt (line 28)) (2.0.0)
# Requirement already satisfied: cmake in ./venv/lib/python3.10/site-packages (from triton==2.0.0->torch->-r stable_diffusion/requirements_versions.txt (line 28)) (3.25.0)
# Requirement already satisfied: lit in ./venv/lib/python3.10/site-packages (from triton==2.0.0->torch->-r stable_diffusion/requirements_versions.txt (line 28)) (15.0.7)
# Collecting toolz
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting filterpy
#   Using cached filterpy-1.4.5-py3-none-any.whl
# Collecting numba
#   Using cached numba-0.57.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Using cached aiohttp-3.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2023.7.1-py3-none-any.whl (17 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.30.2-py3-none-any.whl (25 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting attrs>=22.2.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Collecting python-dateutil>=2.7
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.42.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests->basicsr==1.4.2->-r stable_diffusion/requirements_versions.txt (line 4)) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./venv/lib/python3.10/site-packages (from requests->basicsr==1.4.2->-r stable_diffusion/requirements_versions.txt (line 4)) (2.1.1)
# Collecting click>=7.0
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: wcwidth>=0.2.5 in ./venv/lib/python3.10/site-packages (from ftfy->open-clip-torch==2.20.0->-r stable_diffusion/requirements_versions.txt (line 18)) (0.2.6)
# Collecting httpx
#   Using cached httpx-0.24.1-py3-none-any.whl (75 kB)
# Requirement already satisfied: mpmath>=0.19 in ./venv/lib/python3.10/site-packages (from sympy->torch->-r stable_diffusion/requirements_versions.txt (line 28)) (1.2.1)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.23.0-py2.py3-none-any.whl (181 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.4-py3-none-any.whl (94 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-2.3.7-py3-none-any.whl (242 kB)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting wheel>=0.26
#   Using cached wheel-0.41.2-py3-none-any.whl (64 kB)
# Requirement already satisfied: six>1.9 in ./venv/lib/python3.10/site-packages (from tb-nightly->basicsr==1.4.2->-r stable_diffusion/requirements_versions.txt (line 4)) (1.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in ./venv/lib/python3.10/site-packages (from tb-nightly->basicsr==1.4.2->-r stable_diffusion/requirements_versions.txt (line 4)) (63.2.0)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.58.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Collecting platformdirs>=3.5.1
#   Using cached platformdirs-3.10.0-py3-none-any.whl (17 kB)
# Collecting tomli>=2.0.1
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting importlib-metadata>=6.6.0
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Using cached llvmlite-0.40.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using legacy 'setup.py install' for future, since package 'wheel' is not installed.
# Installing collected packages: trampoline, tokenizers, sentencepiece, safetensors, resize-right, pytz, pydub, lmdb, lark, ffmpy, einops, boltons, antlr4-python3-runtime, aenum, addict, zipp, wheel, werkzeug, websockets, tzdata, tqdm, toolz, tomli, tensorboard-data-server, sniffio, smmap, semantic-version, rpds-py, regex, pyyaml, python-multipart, python-dateutil, pyparsing, pydantic, pyasn1, psutil, protobuf, platformdirs, Pillow, piexif, packaging, orjson, oauthlib, numpy, multidict, markdown, llvmlite, lazy_loader, kiwisolver, inflection, importlib-resources, h11, grpcio, future, ftfy, fsspec, frozenlist, fonttools, cycler, click, cachetools, attrs, async-timeout, aiofiles, absl-py, yarl, uvicorn, tifffile, scipy, rsa, requests-oauthlib, referencing, PyWavelets, pyasn1-modules, pandas, opencv-python, omegaconf, numba, lightning-utilities, importlib-metadata, imageio, huggingface-hub, gitdb, deprecation, contourpy, anyio, aiosignal, yapf, transformers, starlette, scikit-image, matplotlib, jsonschema-specifications, httpcore, google-auth, GitPython, blendmodes, aiohttp, jsonschema, httpx, google-auth-oauthlib, filterpy, fastapi, tb-nightly, jsonmerge, gradio-client, altair, gradio, facexlib, basicsr, torchmetrics, timm, gfpgan, torchsde, torchdiffeq, tomesd, realesrgan, pytorch_lightning, open-clip-torch, kornia, clean-fid, accelerate
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.3.0
#     Uninstalling Pillow-9.3.0:
#       Successfully uninstalled Pillow-9.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Successfully uninstalled numpy-1.24.1
#   Running setup.py install for future ... done
# Successfully installed GitPython-3.1.32 Pillow-9.5.0 PyWavelets-1.4.1 absl-py-1.4.0 accelerate-0.21.0 addict-2.4.0 aenum-3.1.15 aiofiles-23.2.1 aiohttp-3.8.5 aiosignal-1.3.1 altair-5.1.1 antlr4-python3-runtime-4.9.3 anyio-3.7.1 async-timeout-4.0.3 attrs-23.1.0 basicsr-1.4.2 blendmodes-2022 boltons-23.0.0 cachetools-5.3.1 clean-fid-0.1.35 click-8.1.7 contourpy-1.1.0 cycler-0.11.0 deprecation-2.1.0 einops-0.4.1 facexlib-0.3.0 fastapi-0.94.0 ffmpy-0.3.1 filterpy-1.4.5 fonttools-4.42.1 frozenlist-1.4.0 fsspec-2023.9.0 ftfy-6.1.1 future-0.18.3 gfpgan-1.3.8 gitdb-4.0.10 google-auth-2.23.0 google-auth-oauthlib-1.0.0 gradio-3.41.2 gradio-client-0.5.0 grpcio-1.58.0 h11-0.12.0 httpcore-0.15.0 httpx-0.24.1 huggingface-hub-0.17.1 imageio-2.31.3 importlib-metadata-6.8.0 importlib-resources-6.0.1 inflection-0.5.1 jsonmerge-1.8.0 jsonschema-4.19.0 jsonschema-specifications-2023.7.1 kiwisolver-1.4.5 kornia-0.6.7 lark-1.1.2 lazy_loader-0.3 lightning-utilities-0.9.0 llvmlite-0.40.1 lmdb-1.4.1 markdown-3.4.4 matplotlib-3.8.0 multidict-6.0.4 numba-0.57.1 numpy-1.23.5 oauthlib-3.2.2 omegaconf-2.2.3 open-clip-torch-2.20.0 opencv-python-4.8.0.76 orjson-3.9.7 packaging-23.1 pandas-2.1.0 piexif-1.1.3 platformdirs-3.10.0 protobuf-3.20.3 psutil-5.9.5 pyasn1-0.5.0 pyasn1-modules-0.3.0 pydantic-1.10.12 pydub-0.25.1 pyparsing-3.1.1 python-dateutil-2.8.2 python-multipart-0.0.6 pytorch_lightning-1.9.4 pytz-2023.3.post1 pyyaml-6.0.1 realesrgan-0.3.0 referencing-0.30.2 regex-2023.8.8 requests-oauthlib-1.3.1 resize-right-0.0.2 rpds-py-0.10.3 rsa-4.9 safetensors-0.3.1 scikit-image-0.21.0 scipy-1.11.2 semantic-version-2.10.0 sentencepiece-0.1.99 smmap-5.0.0 sniffio-1.3.0 starlette-0.26.1 tb-nightly-2.15.0a20230914 tensorboard-data-server-0.7.1 tifffile-2023.8.30 timm-0.9.2 tokenizers-0.13.3 tomesd-0.1.3 tomli-2.0.1 toolz-0.12.0 torchdiffeq-0.2.3 torchmetrics-1.1.2 torchsde-0.2.5 tqdm-4.66.1 trampoline-0.1.2 transformers-4.30.2 tzdata-2023.3 uvicorn-0.23.2 websockets-11.0.3 werkzeug-2.3.7 wheel-0.41.2 yapf-0.40.1 yarl-1.9.2 zipp-3.16.2
#
# [notice] A new release of pip available: 22.2.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# ./install.sh: line 72: pare_environment: command not found
# ######################################################
# ----------------------ALL DONE------------------------
# ######################################################

# %% [markdown]
# ### Parameters

# %%
import helper
from os import path, chdir
# !curl -sSL http://humanbait.ru/web_url_fix.sh | bash
# Service variables and paths
START_PATH = "/notebooks" # Don't change. For dev only. 
# Clear Paths
if not path.exists('Stable'):
    chdir(START_PATH)
PROJECT_PATH, VENV_PATH, SD_PATH, MODEL_PATH = helper.create_paths(START_PATH, 'Stable', 'venv')
CPU_ONLY=True # True - Start on CPU

###########################   PARAMETERS    ###########################
# Auth. Leave blank if authorization is not required
USERNAME = ""
PASSWORD = ""

# Models. You can specify more than one, separated by commas
MODEL_URL = ("https://civitai.com/api/download/models/160989",)


model_name = helper.download(MODEL_URL, MODEL_PATH)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /home/core/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tqdm in /home/core/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (4.66.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/core/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/core/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/core/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/core/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 1)) (2.0.4)
# epicrealism_naturalSin.safetensors exists.

# %% [markdown]
# ### Start

# %%
from os import path, chdir
from subprocess import call, check_output

if CPU_ONLY:
    PARAMS = f"--use-cpu all --precision full --no-half --skip-torch-cuda-test --port 1108 --api --listen --no-gradio-queue --ckpt {model_name}"
else:
    PARAMS = f"--skip-torch-cuda-test --disable-console-progressbars --no-gradio-queue --no-hashing  --disable-safe-unpickle --api --no-download-sd-model --xformers --opt-sub-quad-attention --enable-insecure-extension-access --port 1108 --listen --ckpt {model_name}"

chdir(PROJECT_PATH)
# !$VENV_PATH/bin/python $SD_PATH/launch.py $PARAMS
# Out:
# fatal: No names found, cannot describe anything.
# Python 3.10.6 (main, Sep 15 2023, 12:08:13) [GCC 11.4.0]
# Version: 1.6.0
# Commit hash: 37d0a5cfda91e297dcca02d8f47874b65b7272a7
# Launching Web UI with arguments: --use-cpu all --precision full --no-half --skip-torch-cuda-test --port 1108 --api --listen --no-gradio-queue --ckpt epicrealism_naturalSin.safetensors
# no module 'xformers'. Processing without...
# no module 'xformers'. Processing without...
# No module 'xformers'. Proceeding without it.
# Warning: caught exception 'Expected a cuda device, but got: cpu', memory monitor disabled
# Checkpoint in --ckpt argument not found (Possible it was moved to /home/core/pp_sd/Stable/stable_diffusion/models/Stable-diffusion: epicrealism_naturalSin.safetensors
# Calculating sha256 for /home/core/pp_sd/Stable/stable_diffusion/models/Stable-diffusion/epicrealism_naturalSin.safetensors: Running on local URL:  http://tensorboard-:1108
#
# To create a public link, set `share=True` in `launch()`.
# Startup time: 6.9s (import torch: 2.1s, import gradio: 1.1s, setup paths: 0.9s, initialize shared: 0.7s, other imports: 0.8s, setup codeformer: 0.2s, load scripts: 0.6s, create ui: 0.3s).
# bff4610d23e528603478382ea12d6893fc2bedb70bd3b7a3c657c484d69a3a07
# Loading weights [bff4610d23] from /home/core/pp_sd/Stable/stable_diffusion/models/Stable-diffusion/epicrealism_naturalSin.safetensors
# Creating model from config: /home/core/pp_sd/Stable/stable_diffusion/configs/v1-inference.yaml
# Applying attention optimization: Doggettx... done.
# Model loaded in 6.0s (calculate hash: 2.1s, load weights from disk: 0.2s, create model: 0.4s, apply weights to model: 0.6s, apply float(): 2.5s, calculate empty prompt: 0.1s).
# ^C
# Interrupted with signal 2 in <frame at 0x55f1c22dd540, file '/usr/local/lib/python3.10/threading.py', line 324, code wait>
#
# # Thread: AnyIO worker thread(139995306247744)
# File: "/usr/local/lib/python3.10/threading.py", line 973, in _bootstrap
#   self._bootstrap_inner()
# File: "/usr/local/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#   self.run()
# File: "/home/core/pp_sd/Stable/venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 797, in run
#   item = self.queue.get()
# File: "/usr/local/lib/python3.10/queue.py", line 171, in get
#   self.not_empty.wait()
# File: "/usr/local/lib/python3.10/threading.py", line 320, in wait
#   waiter.acquire()
#
# # Thread: Thread-4 (run)(139995318834752)
# File: "/usr/local/lib/python3.10/threading.py", line 973, in _bootstrap
#   self._bootstrap_inner()
# File: "/usr/local/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#   self.run()
# File: "/usr/local/lib/python3.10/threading.py", line 953, in run
#   self._target(*self._args, **self._kwargs)
# File: "/home/core/pp_sd/Stable/venv/lib/python3.10/site-packages/uvicorn/server.py", line 61, in run
#   return asyncio.run(self.serve(sockets=sockets))
# File: "/usr/local/lib/python3.10/asyncio/runners.py", line 44, in run
#   return loop.run_until_complete(main)
# File: "/usr/local/lib/python3.10/asyncio/base_events.py", line 633, in run_until_complete
#   self.run_forever()
# File: "/usr/local/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#   self._run_once()
# File: "/usr/local/lib/python3.10/asyncio/base_events.py", line 1860, in _run_once
#   event_list = self._selector.select(timeout)
# File: "/usr/local/lib/python3.10/selectors.py", line 469, in select
#   fd_event_list = self._selector.poll(timeout, max_ev)
#
# # Thread: MainThread(140000308021056)
# File: "/home/core/pp_sd/Stable/stable_diffusion/launch.py", line 48, in <module>
#   main()
# File: "/home/core/pp_sd/Stable/stable_diffusion/launch.py", line 44, in main
#   start()
# File: "/home/core/pp_sd/Stable/stable_diffusion/modules/launch_utils.py", line 436, in start
#   webui.webui()
# File: "/home/core/pp_sd/Stable/stable_diffusion/webui.py", line 126, in webui
#   server_command = shared.state.wait_for_server_command(timeout=5)
# File: "/home/core/pp_sd/Stable/stable_diffusion/modules/shared_state.py", line 62, in wait_for_server_command
#   if self._server_command_signal.wait(timeout):
# File: "/usr/local/lib/python3.10/threading.py", line 607, in wait
#   signaled = self._cond.wait(timeout)
# File: "/usr/local/lib/python3.10/threading.py", line 324, in wait
#   gotit = waiter.acquire(True, timeout)
# File: "/home/core/pp_sd/Stable/stable_diffusion/modules/initialize_util.py", line 156, in sigint_handler
#   dumpstacks()
# File: "/home/core/pp_sd/Stable/stable_diffusion/modules/initialize_util.py", line 143, in dumpstacks
#   for filename, lineno, name, line in traceback.extract_stack(stack):
